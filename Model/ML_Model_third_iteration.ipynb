# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import chi2, f_classif, mutual_info_classif
from itertools import combinations
from scipy import stats as st
import numpy as np
from numpy import argmax

# %%
# Machine learning model libraries 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import RandomOverSampler, SMOTE, BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
from imblearn.ensemble import BalancedRandomForestClassifier

# %%
# Import Dataset
df = pd.read_csv("../Resources/sb_champion_stats.csv", index_col = 1)
df.head()
# Out:
#                         Unnamed: 0  total_tackles_def  sacks_def  safties_def  \
# team_year
# arizona_cardinals_2001           0                670          5            0
# arizona_cardinals_2002           1                547         12            0
# arizona_cardinals_2003           2                548         15            0
# arizona_cardinals_2004           3                511         16            0
# arizona_cardinals_2005           4                483         19            0
#
#                         passes_defended_def  ints_def  fumbles_lost_fum  \
# team_year
# arizona_cardinals_2001                   29        13               7.0
# arizona_cardinals_2002                   24         7               1.0
# arizona_cardinals_2003                   35         8               7.0
# arizona_cardinals_2004                   43         7               7.0
# arizona_cardinals_2005                   27         9              11.0
#
#                         td_passes_pass  ints_pass  sacks_pass  ...  year  \
# team_year                                                      ...
# arizona_cardinals_2001             0.0        0.0         0.0  ...  2001
# arizona_cardinals_2002             0.0        2.0         5.0  ...  2002
# arizona_cardinals_2003             5.0        7.0        25.0  ...  2003
# arizona_cardinals_2004            13.0       18.0        39.0  ...  2004
# arizona_cardinals_2005            21.0       21.0        45.0  ...  2005
#
#                                      team  fg_success_rate extra_success_rate  \
# team_year
# arizona_cardinals_2001  arizona_cardinals         0.833333                1.0
# arizona_cardinals_2002  arizona_cardinals         0.000000                0.0
# arizona_cardinals_2003  arizona_cardinals         0.750000                1.0
# arizona_cardinals_2004  arizona_cardinals         0.758621                1.0
# arizona_cardinals_2005  arizona_cardinals         0.955556                1.0
#
#                         pass_success_rate  avg_yards_pass  avg_yards_rush  \
# team_year
# arizona_cardinals_2001           0.000000       10.715232        3.546939
# arizona_cardinals_2002           0.388889       11.470588        4.256410
# arizona_cardinals_2003           0.568862       12.957831        4.943396
# arizona_cardinals_2004           0.560150       11.369231        3.585034
# arizona_cardinals_2005           0.625373       12.421053        3.541436
#
#                         kicks_blocked  passes_per_rushing_plays  Champion
# team_year
# arizona_cardinals_2001            0.0                  0.004082       0.0
# arizona_cardinals_2002            0.0                  0.461538       0.0
# arizona_cardinals_2003            0.0                  3.150943       0.0
# arizona_cardinals_2004            0.0                  3.619048       0.0
# arizona_cardinals_2005            0.0                  3.701657       0.0
#
# [5 rows x 22 columns]

# %%
# Drop Columns 
df = df.drop(["year", "team", "Unnamed: 0", "extra_success_rate", "fg_success_rate", "kicks_blocked", 
             "safties_def"], axis = 1)
df.shape
# Out:
# (511, 15)

# %%
X = df.drop("Champion", axis = 1)
y = df["Champion"]

# %% [markdown]
# # Scaling Features

# %%
# Generate Scaler instance and scale the data
X_scaled = StandardScaler().fit_transform(X)

# %% [markdown]
# # Adressing Target Variable Imbalance

# %% [markdown]
# ## Target variable imbalance needs to be addressed to avoid overfitting

# %%
# Value counts for target variable shows a minority:majority class ratio of about 1:30
y.value_counts()
# Out:
# 0.0    495
# 1.0     16
# Name: Champion, dtype: int64

# %%
# Prior to addressing the issue, we must split dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=1)

# %% [markdown]
# ## Naive random over and under sampling

# %%
# Naive under sampling will randomly reduce the amount of observations in the majority class to balance outcomes
naive_rus = RandomUnderSampler(random_state=1)
X_naive_rus, y_naive_rus = naive_rus.fit_resample(X_train, y_train)

# %%
# Show results
y_naive_rus.value_counts()
# Out:
# 0.0    10
# 1.0    10
# Name: Champion, dtype: int64

# %%
# Naive over sampling will randomly generate new minority class observations to balance outcomes
naive_ros = RandomOverSampler(random_state=1)
X_naive_ros, y_naive_ros = naive_ros.fit_resample(X_train, y_train)

# %%
# Show results
y_naive_ros.value_counts()
# Out:
# 0.0    373
# 1.0    373
# Name: Champion, dtype: int64

# %%
# We may also apply both sequentially and set the sampling strategy parameter to balance out the outcomes
naive_ros_2 = RandomOverSampler(random_state=1, sampling_strategy=.5)
X_naive_ros_2, y_naive_ros_2 = naive_ros_2.fit_resample(X_train, y_train)

naive_rus_2 = RandomUnderSampler(random_state=1)
X_naive_ros_rus, y_naive_ros_rus = naive_rus_2.fit_resample(X_naive_ros_2, y_naive_ros_2)

# %%
# Show Results
y_naive_ros_rus.value_counts()
# Out:
# 0.0    186
# 1.0    186
# Name: Champion, dtype: int64

# %% [markdown]
# ## SMOTE oversampling

# %%
# Smote oversampling will create synthetic new observations similar to the minority class to balance outcomes
smote = SMOTE(random_state=1)
X_smote, y_smote = smote.fit_resample(X_train, y_train)

# %%
# Show results
y_smote.value_counts()
# Out:
# 0.0    373
# 1.0    373
# Name: Champion, dtype: int64

# %% [markdown]
# ## Combination sampling: SMOTEENN

# %%
# Smoteenn will balance outcomes by utilizing both over and under sampling methods
smoteenn = SMOTEENN(random_state=1)
X_smoteenn, y_smoteenn = smoteenn.fit_resample(X_train, y_train)

# %%
# Show results
y_smoteenn.value_counts()
# Out:
# 1.0    368
# 0.0    264
# Name: Champion, dtype: int64

# %% [markdown]
# # Supervised Learning Models: Fourth Iteration (reduced features; threshold moving)

# %% [markdown]
# ## Logistic Regression

# %%
# Generate model instance
lr_model = LogisticRegression(solver='lbfgs', random_state=1)

# %%
# Define thresholds
thresholds = [.5, .55, .6, .65, .7, .75, .8, .85, .9]

# %%
# Fit on resampled features and predict

## Naive random undersample
lr_model.fit(X_naive_rus, y_naive_rus)
y_lr_naive_rus = lr_model.predict(X_test)
y_lr_naive_rus_probs = lr_model.predict_proba(X_test)[:, 1]

## Naive random oversample
lr_model.fit(X_naive_ros, y_naive_ros)
y_lr_naive_ros = lr_model.predict(X_test)
y_lr_naive_ros_probs = lr_model.predict_proba(X_test)[:, 1]

## Naive ros rus
lr_model.fit(X_naive_ros_rus, y_naive_ros_rus)
y_lr_naive_ros_rus = lr_model.predict(X_test)
y_lr_naive_ros_rus_probs = lr_model.predict_proba(X_test)[:, 1]

## SMOTE
lr_model.fit(X_smote, y_smote)
y_lr_smote = lr_model.predict(X_test)
y_lr_smote_probs = lr_model.predict_proba(X_test)[:, 1]

## SMOTEENN
lr_model.fit(X_smoteenn, y_smoteenn)
y_lr_smoteenn = lr_model.predict(X_test)
y_lr_smoteenn_probs = lr_model.predict_proba(X_test)[:, 1]

# %%
# Display results

## Confusion Matrix, Accuracy Score and Classification Report
for t in thresholds:
    for x in [y_lr_naive_rus_probs, y_lr_naive_ros_probs, y_lr_naive_ros_rus_probs, y_lr_smote_probs, y_lr_smoteenn_probs]:
        print(f"Model: Logistic Regression; Threshold: {t}")
        print("Accuracy Score:")
        print(accuracy_score(y_test, (x >= t).astype(int)))
        print("Confusion Matrix")
        print(confusion_matrix(y_test, (x >= t).astype(int)))
        print("Classification Report")
        print(classification_report(y_test, (x >= t).astype(int)))
        print(" ")
# Out:
# Model: Logistic Regression; Threshold: 0.5
# Accuracy Score:
# 0.515625
# Confusion Matrix
# [[62 60]
#  [ 2  4]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.51      0.67       122
#          1.0       0.06      0.67      0.11         6
#
#     accuracy                           0.52       128
#    macro avg       0.52      0.59      0.39       128
# weighted avg       0.93      0.52      0.64       128
#
#
# Model: Logistic Regression; Threshold: 0.5
# Accuracy Score:
# 0.78125
# Confusion Matrix
# [[98 24]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.80      0.88       122
#          1.0       0.08      0.33      0.12         6
#
#     accuracy                           0.78       128
#    macro avg       0.52      0.57      0.50       128
# weighted avg       0.92      0.78      0.84       128
#
#
# Model: Logistic Regression; Threshold: 0.5
# Accuracy Score:
# 0.765625
# Confusion Matrix
# [[96 26]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.79      0.86       122
#          1.0       0.07      0.33      0.12         6
#
#     accuracy                           0.77       128
#    macro avg       0.52      0.56      0.49       128
# weighted avg       0.92      0.77      0.83       128
#
#
# Model: Logistic Regression; Threshold: 0.5
# Accuracy Score:
# 0.7578125
# Confusion Matrix
# [[95 27]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.78      0.86       122
#          1.0       0.07      0.33      0.11         6
#
#     accuracy                           0.76       128
#    macro avg       0.51      0.56      0.49       128
# weighted avg       0.92      0.76      0.82       128
#
#
# Model: Logistic Regression; Threshold: 0.5
# Accuracy Score:
# 0.734375
# Confusion Matrix
# [[92 30]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.75      0.84       122
#          1.0       0.06      0.33      0.11         6
#
#     accuracy                           0.73       128
#    macro avg       0.51      0.54      0.47       128
# weighted avg       0.92      0.73      0.81       128
#
#
# Model: Logistic Regression; Threshold: 0.55
# Accuracy Score:
# 0.5546875
# Confusion Matrix
# [[67 55]
#  [ 2  4]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.55      0.70       122
#          1.0       0.07      0.67      0.12         6
#
#     accuracy                           0.55       128
#    macro avg       0.52      0.61      0.41       128
# weighted avg       0.93      0.55      0.67       128
#
#
# Model: Logistic Regression; Threshold: 0.55
# Accuracy Score:
# 0.7890625
# Confusion Matrix
# [[99 23]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.81      0.88       122
#          1.0       0.08      0.33      0.13         6
#
#     accuracy                           0.79       128
#    macro avg       0.52      0.57      0.50       128
# weighted avg       0.92      0.79      0.84       128
#
#
# Model: Logistic Regression; Threshold: 0.55
# Accuracy Score:
# 0.796875
# Confusion Matrix
# [[100  22]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.82      0.88       122
#          1.0       0.08      0.33      0.13         6
#
#     accuracy                           0.80       128
#    macro avg       0.52      0.58      0.51       128
# weighted avg       0.92      0.80      0.85       128
#
#
# Model: Logistic Regression; Threshold: 0.55
# Accuracy Score:
# 0.8046875
# Confusion Matrix
# [[101  21]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.83      0.89       122
#          1.0       0.09      0.33      0.14         6
#
#     accuracy                           0.80       128
#    macro avg       0.52      0.58      0.51       128
# weighted avg       0.92      0.80      0.85       128
#
#
# Model: Logistic Regression; Threshold: 0.55
# Accuracy Score:
# 0.7421875
# Confusion Matrix
# [[93 29]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.76      0.85       122
#          1.0       0.06      0.33      0.11         6
#
#     accuracy                           0.74       128
#    macro avg       0.51      0.55      0.48       128
# weighted avg       0.92      0.74      0.81       128
#
#
# Model: Logistic Regression; Threshold: 0.6
# Accuracy Score:
# 0.609375
# Confusion Matrix
# [[75 47]
#  [ 3  3]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.61      0.75       122
#          1.0       0.06      0.50      0.11         6
#
#     accuracy                           0.61       128
#    macro avg       0.51      0.56      0.43       128
# weighted avg       0.92      0.61      0.72       128
#
#
# Model: Logistic Regression; Threshold: 0.6
# Accuracy Score:
# 0.8203125
# Confusion Matrix
# [[103  19]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.84      0.90       122
#          1.0       0.10      0.33      0.15         6
#
#     accuracy                           0.82       128
#    macro avg       0.53      0.59      0.52       128
# weighted avg       0.92      0.82      0.86       128
#
#
# Model: Logistic Regression; Threshold: 0.6
# Accuracy Score:
# 0.8203125
# Confusion Matrix
# [[103  19]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.84      0.90       122
#          1.0       0.10      0.33      0.15         6
#
#     accuracy                           0.82       128
#    macro avg       0.53      0.59      0.52       128
# weighted avg       0.92      0.82      0.86       128
#
#
# Model: Logistic Regression; Threshold: 0.6
# Accuracy Score:
# 0.8359375
# Confusion Matrix
# [[105  17]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.86      0.91       122
#          1.0       0.11      0.33      0.16         6
#
#     accuracy                           0.84       128
#    macro avg       0.53      0.60      0.53       128
# weighted avg       0.92      0.84      0.87       128
#
#
# Model: Logistic Regression; Threshold: 0.6
# Accuracy Score:
# 0.7578125
# Confusion Matrix
# [[95 27]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.78      0.86       122
#          1.0       0.07      0.33      0.11         6
#
#     accuracy                           0.76       128
#    macro avg       0.51      0.56      0.49       128
# weighted avg       0.92      0.76      0.82       128
#
#
# Model: Logistic Regression; Threshold: 0.65
# Accuracy Score:
# 0.7109375
# Confusion Matrix
# [[88 34]
#  [ 3  3]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.72      0.83       122
#          1.0       0.08      0.50      0.14         6
#
#     accuracy                           0.71       128
#    macro avg       0.52      0.61      0.48       128
# weighted avg       0.93      0.71      0.79       128
#
#
# Model: Logistic Regression; Threshold: 0.65
# Accuracy Score:
# 0.8671875
# Confusion Matrix
# [[109  13]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.89      0.93       122
#          1.0       0.13      0.33      0.19         6
#
#     accuracy                           0.87       128
#    macro avg       0.55      0.61      0.56       128
# weighted avg       0.93      0.87      0.89       128
#
#
# Model: Logistic Regression; Threshold: 0.65
# Accuracy Score:
# 0.8203125
# Confusion Matrix
# [[103  19]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.84      0.90       122
#          1.0       0.10      0.33      0.15         6
#
#     accuracy                           0.82       128
#    macro avg       0.53      0.59      0.52       128
# weighted avg       0.92      0.82      0.86       128
#
#
# Model: Logistic Regression; Threshold: 0.65
# Accuracy Score:
# 0.8671875
# Confusion Matrix
# [[109  13]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.89      0.93       122
#          1.0       0.13      0.33      0.19         6
#
#     accuracy                           0.87       128
#    macro avg       0.55      0.61      0.56       128
# weighted avg       0.93      0.87      0.89       128
#
#
# Model: Logistic Regression; Threshold: 0.65
# Accuracy Score:
# 0.78125
# Confusion Matrix
# [[98 24]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.80      0.88       122
#          1.0       0.08      0.33      0.12         6
#
#     accuracy                           0.78       128
#    macro avg       0.52      0.57      0.50       128
# weighted avg       0.92      0.78      0.84       128
#
#
# Model: Logistic Regression; Threshold: 0.7
# Accuracy Score:
# 0.75
# Confusion Matrix
# [[95 27]
#  [ 5  1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.78      0.86       122
#          1.0       0.04      0.17      0.06         6
#
#     accuracy                           0.75       128
#    macro avg       0.49      0.47      0.46       128
# weighted avg       0.91      0.75      0.82       128
#
#
# Model: Logistic Regression; Threshold: 0.7
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[113   9]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.18      0.33      0.24         6
#
#     accuracy                           0.90       128
#    macro avg       0.57      0.63      0.59       128
# weighted avg       0.93      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.7
# Accuracy Score:
# 0.8515625
# Confusion Matrix
# [[107  15]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.88      0.92       122
#          1.0       0.12      0.33      0.17         6
#
#     accuracy                           0.85       128
#    macro avg       0.54      0.61      0.55       128
# weighted avg       0.92      0.85      0.88       128
#
#
# Model: Logistic Regression; Threshold: 0.7
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[112  10]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       122
#          1.0       0.17      0.33      0.22         6
#
#     accuracy                           0.89       128
#    macro avg       0.57      0.63      0.58       128
# weighted avg       0.93      0.89      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.7
# Accuracy Score:
# 0.8125
# Confusion Matrix
# [[102  20]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.84      0.89       122
#          1.0       0.09      0.33      0.14         6
#
#     accuracy                           0.81       128
#    macro avg       0.53      0.58      0.52       128
# weighted avg       0.92      0.81      0.86       128
#
#
# Model: Logistic Regression; Threshold: 0.75
# Accuracy Score:
# 0.8515625
# Confusion Matrix
# [[108  14]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.89      0.92       122
#          1.0       0.07      0.17      0.10         6
#
#     accuracy                           0.85       128
#    macro avg       0.51      0.53      0.51       128
# weighted avg       0.91      0.85      0.88       128
#
#
# Model: Logistic Regression; Threshold: 0.75
# Accuracy Score:
# 0.9140625
# Confusion Matrix
# [[115   7]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95       122
#          1.0       0.22      0.33      0.27         6
#
#     accuracy                           0.91       128
#    macro avg       0.59      0.64      0.61       128
# weighted avg       0.93      0.91      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.75
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[112  10]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       122
#          1.0       0.17      0.33      0.22         6
#
#     accuracy                           0.89       128
#    macro avg       0.57      0.63      0.58       128
# weighted avg       0.93      0.89      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.75
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[114   8]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.20      0.33      0.25         6
#
#     accuracy                           0.91       128
#    macro avg       0.58      0.63      0.60       128
# weighted avg       0.93      0.91      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.75
# Accuracy Score:
# 0.8203125
# Confusion Matrix
# [[104  18]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.85      0.90       122
#          1.0       0.05      0.17      0.08         6
#
#     accuracy                           0.82       128
#    macro avg       0.50      0.51      0.49       128
# weighted avg       0.91      0.82      0.86       128
#
#
# Model: Logistic Regression; Threshold: 0.8
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[115   7]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       122
#          1.0       0.12      0.17      0.14         6
#
#     accuracy                           0.91       128
#    macro avg       0.54      0.55      0.55       128
# weighted avg       0.92      0.91      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.8
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[115   7]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       122
#          1.0       0.12      0.17      0.14         6
#
#     accuracy                           0.91       128
#    macro avg       0.54      0.55      0.55       128
# weighted avg       0.92      0.91      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.8
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[114   8]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.95       122
#          1.0       0.11      0.17      0.13         6
#
#     accuracy                           0.90       128
#    macro avg       0.53      0.55      0.54       128
# weighted avg       0.92      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.8
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[114   8]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.95       122
#          1.0       0.11      0.17      0.13         6
#
#     accuracy                           0.90       128
#    macro avg       0.53      0.55      0.54       128
# weighted avg       0.92      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.8
# Accuracy Score:
# 0.8359375
# Confusion Matrix
# [[106  16]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.87      0.91       122
#          1.0       0.06      0.17      0.09         6
#
#     accuracy                           0.84       128
#    macro avg       0.51      0.52      0.50       128
# weighted avg       0.91      0.84      0.87       128
#
#
# Model: Logistic Regression; Threshold: 0.85
# Accuracy Score:
# 0.9375
# Confusion Matrix
# [[119   3]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97       122
#          1.0       0.25      0.17      0.20         6
#
#     accuracy                           0.94       128
#    macro avg       0.60      0.57      0.58       128
# weighted avg       0.93      0.94      0.93       128
#
#
# Model: Logistic Regression; Threshold: 0.85
# Accuracy Score:
# 0.921875
# Confusion Matrix
# [[117   5]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96       122
#          1.0       0.17      0.17      0.17         6
#
#     accuracy                           0.92       128
#    macro avg       0.56      0.56      0.56       128
# weighted avg       0.92      0.92      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.85
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[115   7]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       122
#          1.0       0.12      0.17      0.14         6
#
#     accuracy                           0.91       128
#    macro avg       0.54      0.55      0.55       128
# weighted avg       0.92      0.91      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.85
# Accuracy Score:
# 0.921875
# Confusion Matrix
# [[117   5]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96       122
#          1.0       0.17      0.17      0.17         6
#
#     accuracy                           0.92       128
#    macro avg       0.56      0.56      0.56       128
# weighted avg       0.92      0.92      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.85
# Accuracy Score:
# 0.8828125
# Confusion Matrix
# [[112  10]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94       122
#          1.0       0.09      0.17      0.12         6
#
#     accuracy                           0.88       128
#    macro avg       0.52      0.54      0.53       128
# weighted avg       0.92      0.88      0.90       128
#
#
# Model: Logistic Regression; Threshold: 0.9
# Accuracy Score:
# 0.9609375
# Confusion Matrix
# [[122   0]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98       122
#          1.0       1.00      0.17      0.29         6
#
#     accuracy                           0.96       128
#    macro avg       0.98      0.58      0.63       128
# weighted avg       0.96      0.96      0.95       128
#
#
# Model: Logistic Regression; Threshold: 0.9
# Accuracy Score:
# 0.921875
# Confusion Matrix
# [[117   5]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96       122
#          1.0       0.17      0.17      0.17         6
#
#     accuracy                           0.92       128
#    macro avg       0.56      0.56      0.56       128
# weighted avg       0.92      0.92      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.9
# Accuracy Score:
# 0.9296875
# Confusion Matrix
# [[118   4]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96       122
#          1.0       0.20      0.17      0.18         6
#
#     accuracy                           0.93       128
#    macro avg       0.58      0.57      0.57       128
# weighted avg       0.92      0.93      0.93       128
#
#
# Model: Logistic Regression; Threshold: 0.9
# Accuracy Score:
# 0.9375
# Confusion Matrix
# [[119   3]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97       122
#          1.0       0.25      0.17      0.20         6
#
#     accuracy                           0.94       128
#    macro avg       0.60      0.57      0.58       128
# weighted avg       0.93      0.94      0.93       128
#
#
# Model: Logistic Regression; Threshold: 0.9
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[114   8]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.95       122
#          1.0       0.11      0.17      0.13         6
#
#     accuracy                           0.90       128
#    macro avg       0.53      0.55      0.54       128
# weighted avg       0.92      0.90      0.91       128

# %% [markdown]
# ## Random Forest Classifier

# %%
# Generate model instance
rf_model = RandomForestClassifier(n_estimators=400, random_state=1)

# %%
# Fit on resampled features and predict

## Naive random undersample
rf_model.fit(X_naive_rus, y_naive_rus)
y_rf_naive_rus = rf_model.predict(X_test)
y_rf_naive_rus_probs = rf_model.predict_proba(X_test)[:, 1]

## Naive random oversample
rf_model.fit(X_naive_ros, y_naive_ros)
y_rf_naive_ros = rf_model.predict(X_test)
y_rf_naive_ros_probs = rf_model.predict_proba(X_test)[:, 1]

## Naive ros rus
rf_model.fit(X_naive_ros_rus, y_naive_ros_rus)
y_rf_naive_ros_rus = rf_model.predict(X_test)
y_rf_naive_ros_rus_probs = rf_model.predict_proba(X_test)[:, 1]

## SMOTE
rf_model.fit(X_smote, y_smote)
y_rf_smote = rf_model.predict(X_test)
y_rf_smote_probs = rf_model.predict_proba(X_test)[:, 1]

## SMOTEENN
rf_model.fit(X_smoteenn, y_smoteenn)
y_rf_smoteenn = rf_model.predict(X_test)
y_rf_smoteenn_probs = rf_model.predict_proba(X_test)[:, 1]

# %%
# Display results

## Confusion Matrix, Accuracy Score and Classification Report
for t in thresholds:
    for x in [y_rf_naive_rus_probs, y_rf_naive_ros_probs, y_rf_naive_ros_rus_probs, y_rf_smote_probs, y_rf_smoteenn_probs]:
        print(f"Model: Random Forest Classifier; Threshold: {t}")
        print("Accuracy Score:")
        print(accuracy_score(y_test, (x >= t).astype(int)))
        print("Confusion Matrix")
        print(confusion_matrix(y_test, (x >= t).astype(int)))
        print("Classification Report")
        print(classification_report(y_test, (x >= t).astype(int)))
        print(" ")
# Out:
# Model: Random Forest Classifier; Threshold: 0.5
# Accuracy Score:
# 0.421875
# Confusion Matrix
# [[50 72]
#  [ 2  4]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.41      0.57       122
#          1.0       0.05      0.67      0.10         6
#
#     accuracy                           0.42       128
#    macro avg       0.51      0.54      0.34       128
# weighted avg       0.92      0.42      0.55       128
#
#
# Model: Random Forest Classifier; Threshold: 0.5
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.5
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.5
# Accuracy Score:
# 0.9375
# Confusion Matrix
# [[120   2]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.94       128
#    macro avg       0.48      0.49      0.48       128
# weighted avg       0.91      0.94      0.92       128
#
#
# Model: Random Forest Classifier; Threshold: 0.5
# Accuracy Score:
# 0.8671875
# Confusion Matrix
# [[111  11]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.91      0.93       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.87       128
#    macro avg       0.47      0.45      0.46       128
# weighted avg       0.90      0.87      0.89       128
#
#
# Model: Random Forest Classifier; Threshold: 0.55
# Accuracy Score:
# 0.5625
# Confusion Matrix
# [[70 52]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.57      0.71       122
#          1.0       0.04      0.33      0.07         6
#
#     accuracy                           0.56       128
#    macro avg       0.49      0.45      0.39       128
# weighted avg       0.90      0.56      0.68       128
#
#
# Model: Random Forest Classifier; Threshold: 0.55
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.55
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.55
# Accuracy Score:
# 0.9375
# Confusion Matrix
# [[120   2]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.94       128
#    macro avg       0.48      0.49      0.48       128
# weighted avg       0.91      0.94      0.92       128
#
#
# Model: Random Forest Classifier; Threshold: 0.55
# Accuracy Score:
# 0.8828125
# Confusion Matrix
# [[113   9]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.93      0.94       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.88       128
#    macro avg       0.47      0.46      0.47       128
# weighted avg       0.91      0.88      0.89       128
#
#
# Model: Random Forest Classifier; Threshold: 0.6
# Accuracy Score:
# 0.6796875
# Confusion Matrix
# [[85 37]
#  [ 4  2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.70      0.81       122
#          1.0       0.05      0.33      0.09         6
#
#     accuracy                           0.68       128
#    macro avg       0.50      0.52      0.45       128
# weighted avg       0.91      0.68      0.77       128
#
#
# Model: Random Forest Classifier; Threshold: 0.6
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.6
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.6
# Accuracy Score:
# 0.9453125
# Confusion Matrix
# [[121   1]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.6
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[114   8]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.93      0.94       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.89       128
#    macro avg       0.47      0.47      0.47       128
# weighted avg       0.91      0.89      0.90       128
#
#
# Model: Random Forest Classifier; Threshold: 0.65
# Accuracy Score:
# 0.8203125
# Confusion Matrix
# [[103  19]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.84      0.90       122
#          1.0       0.10      0.33      0.15         6
#
#     accuracy                           0.82       128
#    macro avg       0.53      0.59      0.52       128
# weighted avg       0.92      0.82      0.86       128
#
#
# Model: Random Forest Classifier; Threshold: 0.65
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.65
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.65
# Accuracy Score:
# 0.9453125
# Confusion Matrix
# [[121   1]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.65
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[116   6]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.91       128
#    macro avg       0.48      0.48      0.48       128
# weighted avg       0.91      0.91      0.91       128
#
#
# Model: Random Forest Classifier; Threshold: 0.7
# Accuracy Score:
# 0.8828125
# Confusion Matrix
# [[113   9]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.93      0.94       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.88       128
#    macro avg       0.47      0.46      0.47       128
# weighted avg       0.91      0.88      0.89       128
#
#
# Model: Random Forest Classifier; Threshold: 0.7
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.7
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.7
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.7
# Accuracy Score:
# 0.9375
# Confusion Matrix
# [[120   2]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.94       128
#    macro avg       0.48      0.49      0.48       128
# weighted avg       0.91      0.94      0.92       128
#
#
# Model: Random Forest Classifier; Threshold: 0.75
# Accuracy Score:
# 0.9375
# Confusion Matrix
# [[120   2]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.94       128
#    macro avg       0.48      0.49      0.48       128
# weighted avg       0.91      0.94      0.92       128
#
#
# Model: Random Forest Classifier; Threshold: 0.75
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.75
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.75
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.75
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.8
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.8
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.8
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.8
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.8
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.85
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.85
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.85
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.85
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.85
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.9
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.9
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.9
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.9
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Random Forest Classifier; Threshold: 0.9
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Balanced Random Forest Classifier

# %%
# Generate Imbalanced Random Forest Classier instance
irf_model = BalancedRandomForestClassifier(n_estimators=250, random_state=1)

# %%
# Fit on features and predict
irf_model.fit(X_train, y_train)
y_irf = irf_model.predict(X_test)
y_irf_probs = irf_model.predict_proba(X_test)[:, 1]

# %%
# Display results
for t in thresholds:
    print(f"Model: Balanced Random Forest Classifier; Threshold: {t}")
    print("Accuracy Score:")
    print(accuracy_score(y_test, (y_irf_probs >= t).astype(int)))
    print("Confusion Matrix")
    print(confusion_matrix(y_test, (y_irf_probs >= t).astype(int)))
    print("Classification Report")
    print(classification_report(y_test, (y_irf_probs >= t).astype(int)))
    print(" ")
# Out:
# Model: Balanced Random Forest Classifier; Threshold: 0.5
# Accuracy Score:
# 0.5625
# Confusion Matrix
# [[68 54]
#  [ 2  4]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.56      0.71       122
#          1.0       0.07      0.67      0.12         6
#
#     accuracy                           0.56       128
#    macro avg       0.52      0.61      0.42       128
# weighted avg       0.93      0.56      0.68       128
#
#
# Model: Balanced Random Forest Classifier; Threshold: 0.55
# Accuracy Score:
# 0.6953125
# Confusion Matrix
# [[85 37]
#  [ 2  4]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.70      0.81       122
#          1.0       0.10      0.67      0.17         6
#
#     accuracy                           0.70       128
#    macro avg       0.54      0.68      0.49       128
# weighted avg       0.94      0.70      0.78       128
#
#
# Model: Balanced Random Forest Classifier; Threshold: 0.6
# Accuracy Score:
# 0.828125
# Confusion Matrix
# [[104  18]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.85      0.90       122
#          1.0       0.10      0.33      0.15         6
#
#     accuracy                           0.83       128
#    macro avg       0.53      0.59      0.53       128
# weighted avg       0.92      0.83      0.87       128
#
#
# Model: Balanced Random Forest Classifier; Threshold: 0.65
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[115   7]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.90       128
#    macro avg       0.48      0.47      0.47       128
# weighted avg       0.91      0.90      0.90       128
#
#
# Model: Balanced Random Forest Classifier; Threshold: 0.7
# Accuracy Score:
# 0.9375
# Confusion Matrix
# [[120   2]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.94       128
#    macro avg       0.48      0.49      0.48       128
# weighted avg       0.91      0.94      0.92       128
#
#
# Model: Balanced Random Forest Classifier; Threshold: 0.75
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Balanced Random Forest Classifier; Threshold: 0.8
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Balanced Random Forest Classifier; Threshold: 0.85
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
#
#
# Model: Balanced Random Forest Classifier; Threshold: 0.9
# Accuracy Score:
# 0.953125
# Confusion Matrix
# [[122   0]
#  [  6   0]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       122
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.95       128
#    macro avg       0.48      0.50      0.49       128
# weighted avg       0.91      0.95      0.93       128
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Alvarado/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Analyzing threshold values between .7-.8 in logistic regression

# %%
# Generate model instance
lr_model = LogisticRegression(solver='lbfgs', random_state=1)

# %%
# Define thresholds
thresholds = [.7, .71, .72, .73, .74, .75, .76, .77, .78, .79]

# %%
# Display results

## Confusion Matrix, Accuracy Score and Classification Report
for t in thresholds:
    for x in [y_lr_naive_ros_probs, y_lr_naive_ros_rus_probs, y_lr_smote_probs]:
        print(f"Model: Logistic Regression; Threshold: {t}")
        print("Accuracy Score:")
        print(accuracy_score(y_test, (x >= t).astype(int)))
        print("Confusion Matrix")
        print(confusion_matrix(y_test, (x >= t).astype(int)))
        print("Classification Report")
        print(classification_report(y_test, (x >= t).astype(int)))
        print(" ")
# Out:
# Model: Logistic Regression; Threshold: 0.7
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[113   9]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.18      0.33      0.24         6
#
#     accuracy                           0.90       128
#    macro avg       0.57      0.63      0.59       128
# weighted avg       0.93      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.7
# Accuracy Score:
# 0.8515625
# Confusion Matrix
# [[107  15]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.88      0.92       122
#          1.0       0.12      0.33      0.17         6
#
#     accuracy                           0.85       128
#    macro avg       0.54      0.61      0.55       128
# weighted avg       0.92      0.85      0.88       128
#
#
# Model: Logistic Regression; Threshold: 0.7
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[112  10]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       122
#          1.0       0.17      0.33      0.22         6
#
#     accuracy                           0.89       128
#    macro avg       0.57      0.63      0.58       128
# weighted avg       0.93      0.89      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.71
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[113   9]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.18      0.33      0.24         6
#
#     accuracy                           0.90       128
#    macro avg       0.57      0.63      0.59       128
# weighted avg       0.93      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.71
# Accuracy Score:
# 0.8671875
# Confusion Matrix
# [[109  13]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.89      0.93       122
#          1.0       0.13      0.33      0.19         6
#
#     accuracy                           0.87       128
#    macro avg       0.55      0.61      0.56       128
# weighted avg       0.93      0.87      0.89       128
#
#
# Model: Logistic Regression; Threshold: 0.71
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[112  10]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       122
#          1.0       0.17      0.33      0.22         6
#
#     accuracy                           0.89       128
#    macro avg       0.57      0.63      0.58       128
# weighted avg       0.93      0.89      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.72
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[113   9]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.18      0.33      0.24         6
#
#     accuracy                           0.90       128
#    macro avg       0.57      0.63      0.59       128
# weighted avg       0.93      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.72
# Accuracy Score:
# 0.875
# Confusion Matrix
# [[110  12]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.90      0.93       122
#          1.0       0.14      0.33      0.20         6
#
#     accuracy                           0.88       128
#    macro avg       0.55      0.62      0.57       128
# weighted avg       0.93      0.88      0.90       128
#
#
# Model: Logistic Regression; Threshold: 0.72
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[112  10]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       122
#          1.0       0.17      0.33      0.22         6
#
#     accuracy                           0.89       128
#    macro avg       0.57      0.63      0.58       128
# weighted avg       0.93      0.89      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.73
# Accuracy Score:
# 0.9140625
# Confusion Matrix
# [[115   7]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95       122
#          1.0       0.22      0.33      0.27         6
#
#     accuracy                           0.91       128
#    macro avg       0.59      0.64      0.61       128
# weighted avg       0.93      0.91      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.73
# Accuracy Score:
# 0.8828125
# Confusion Matrix
# [[111  11]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.91      0.94       122
#          1.0       0.15      0.33      0.21         6
#
#     accuracy                           0.88       128
#    macro avg       0.56      0.62      0.57       128
# weighted avg       0.93      0.88      0.90       128
#
#
# Model: Logistic Regression; Threshold: 0.73
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[113   9]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.18      0.33      0.24         6
#
#     accuracy                           0.90       128
#    macro avg       0.57      0.63      0.59       128
# weighted avg       0.93      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.74
# Accuracy Score:
# 0.9140625
# Confusion Matrix
# [[115   7]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95       122
#          1.0       0.22      0.33      0.27         6
#
#     accuracy                           0.91       128
#    macro avg       0.59      0.64      0.61       128
# weighted avg       0.93      0.91      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.74
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[112  10]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       122
#          1.0       0.17      0.33      0.22         6
#
#     accuracy                           0.89       128
#    macro avg       0.57      0.63      0.58       128
# weighted avg       0.93      0.89      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.74
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[114   8]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.20      0.33      0.25         6
#
#     accuracy                           0.91       128
#    macro avg       0.58      0.63      0.60       128
# weighted avg       0.93      0.91      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.75
# Accuracy Score:
# 0.9140625
# Confusion Matrix
# [[115   7]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95       122
#          1.0       0.22      0.33      0.27         6
#
#     accuracy                           0.91       128
#    macro avg       0.59      0.64      0.61       128
# weighted avg       0.93      0.91      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.75
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[112  10]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       122
#          1.0       0.17      0.33      0.22         6
#
#     accuracy                           0.89       128
#    macro avg       0.57      0.63      0.58       128
# weighted avg       0.93      0.89      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.75
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[114   8]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.20      0.33      0.25         6
#
#     accuracy                           0.91       128
#    macro avg       0.58      0.63      0.60       128
# weighted avg       0.93      0.91      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.76
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[115   7]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       122
#          1.0       0.12      0.17      0.14         6
#
#     accuracy                           0.91       128
#    macro avg       0.54      0.55      0.55       128
# weighted avg       0.92      0.91      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.76
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[112  10]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       122
#          1.0       0.17      0.33      0.22         6
#
#     accuracy                           0.89       128
#    macro avg       0.57      0.63      0.58       128
# weighted avg       0.93      0.89      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.76
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[114   8]
#  [  4   2]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       122
#          1.0       0.20      0.33      0.25         6
#
#     accuracy                           0.91       128
#    macro avg       0.58      0.63      0.60       128
# weighted avg       0.93      0.91      0.92       128
#
#
# Model: Logistic Regression; Threshold: 0.77
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[115   7]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       122
#          1.0       0.12      0.17      0.14         6
#
#     accuracy                           0.91       128
#    macro avg       0.54      0.55      0.55       128
# weighted avg       0.92      0.91      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.77
# Accuracy Score:
# 0.8828125
# Confusion Matrix
# [[112  10]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94       122
#          1.0       0.09      0.17      0.12         6
#
#     accuracy                           0.88       128
#    macro avg       0.52      0.54      0.53       128
# weighted avg       0.92      0.88      0.90       128
#
#
# Model: Logistic Regression; Threshold: 0.77
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[114   8]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.95       122
#          1.0       0.11      0.17      0.13         6
#
#     accuracy                           0.90       128
#    macro avg       0.53      0.55      0.54       128
# weighted avg       0.92      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.78
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[115   7]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       122
#          1.0       0.12      0.17      0.14         6
#
#     accuracy                           0.91       128
#    macro avg       0.54      0.55      0.55       128
# weighted avg       0.92      0.91      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.78
# Accuracy Score:
# 0.8828125
# Confusion Matrix
# [[112  10]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94       122
#          1.0       0.09      0.17      0.12         6
#
#     accuracy                           0.88       128
#    macro avg       0.52      0.54      0.53       128
# weighted avg       0.92      0.88      0.90       128
#
#
# Model: Logistic Regression; Threshold: 0.78
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[114   8]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.95       122
#          1.0       0.11      0.17      0.13         6
#
#     accuracy                           0.90       128
#    macro avg       0.53      0.55      0.54       128
# weighted avg       0.92      0.90      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.79
# Accuracy Score:
# 0.90625
# Confusion Matrix
# [[115   7]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       122
#          1.0       0.12      0.17      0.14         6
#
#     accuracy                           0.91       128
#    macro avg       0.54      0.55      0.55       128
# weighted avg       0.92      0.91      0.91       128
#
#
# Model: Logistic Regression; Threshold: 0.79
# Accuracy Score:
# 0.890625
# Confusion Matrix
# [[113   9]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.94       122
#          1.0       0.10      0.17      0.12         6
#
#     accuracy                           0.89       128
#    macro avg       0.53      0.55      0.53       128
# weighted avg       0.92      0.89      0.90       128
#
#
# Model: Logistic Regression; Threshold: 0.79
# Accuracy Score:
# 0.8984375
# Confusion Matrix
# [[114   8]
#  [  5   1]]
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.95       122
#          1.0       0.11      0.17      0.13         6
#
#     accuracy                           0.90       128
#    macro avg       0.53      0.55      0.54       128
# weighted avg       0.92      0.90      0.91       128

# %% [markdown]
# # Best Performing Model: Logistic Regression with a .75 decision threshold and utilizing Naive Random Oversampling
